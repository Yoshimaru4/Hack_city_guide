# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/combined_details.csv')

# %%
df
# Out:
#      Category                                               Name  \
# 0      places                                     Воробьёвы горы
# 1      places                                  Лефортовский парк
# 2      places                           Большая Грузинская улица
# 3      places                                 Трифоновская улица
# 4      places                         Каток в саду имени Баумана
# ...       ...                                                ...
# 3535   houses  Фреска «Народное гуляние в Киеве» на станции м...
# 3536   houses                             Театр на Малой Ордынке
# 3537   houses            Павильон станции метро «Красные ворота»
# 3538   houses                                        Дом Перцова
# 3539   houses                               Особняк Рябушинского
#
#                                                     Geo  \
# 0                                      ул. Косыгина, 28
# 1                              Красноказарменная ул., 3
# ...

# %%
# !pip install geopy tqdm
